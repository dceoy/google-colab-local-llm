# %%
# !curl -sSL https://raw.githubusercontent.com/dceoy/google-colab-local-llm/main/test-sdeul.sh | bash
# Out:
# + head -20 /etc/lsb-release /etc/os-release
# ==> /etc/lsb-release <==
# DISTRIB_ID=Ubuntu
# DISTRIB_RELEASE=22.04
# DISTRIB_CODENAME=jammy
# DISTRIB_DESCRIPTION="Ubuntu 22.04.3 LTS"
#
# ==> /etc/os-release <==
# PRETTY_NAME="Ubuntu 22.04.3 LTS"
# NAME="Ubuntu"
# VERSION_ID="22.04"
# VERSION="22.04.3 LTS (Jammy Jellyfish)"
# VERSION_CODENAME=jammy
# ID=ubuntu
# ID_LIKE=debian
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# UBUNTU_CODENAME=jammy
# + df -Th
# Filesystem     Type     Size  Used Avail Use% Mounted on
# overlay        overlay  202G   41G  161G  21% /
# tmpfs          tmpfs     64M     0   64M   0% /dev
# shm            tmpfs     25G     0   25G   0% /dev/shm
# /dev/root      ext2     2.0G  1.1G  849M  57% /usr/sbin/docker-init
# tmpfs          tmpfs     26G   56K   26G   1% /var/colab
# ...
