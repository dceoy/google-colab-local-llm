# %%
# !curl -sSL https://raw.githubusercontent.com/dceoy/google-colab-local-llm/main/install-text-generation-webui.sh | bash
# Out:
# + head -20 /etc/lsb-release /etc/os-release
# ==> /etc/lsb-release <==
# DISTRIB_ID=Ubuntu
# DISTRIB_RELEASE=22.04
# DISTRIB_CODENAME=jammy
# DISTRIB_DESCRIPTION="Ubuntu 22.04.3 LTS"
#
# ==> /etc/os-release <==
# PRETTY_NAME="Ubuntu 22.04.3 LTS"
# NAME="Ubuntu"
# VERSION_ID="22.04"
# VERSION="22.04.3 LTS (Jammy Jellyfish)"
# VERSION_CODENAME=jammy
# ID=ubuntu
# ID_LIKE=debian
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# UBUNTU_CODENAME=jammy
# + df -Th
# Filesystem     Type     Size  Used Avail Use% Mounted on
# overlay        overlay  202G   25G  177G  13% /
# tmpfs          tmpfs     64M     0   64M   0% /dev
# shm            tmpfs     41G     0   41G   0% /dev/shm
# /dev/root      ext2     2.0G  1.1G  849M  57% /usr/sbin/docker-init
# tmpfs          tmpfs     42G   19M   42G   1% /var/colab
# ...

# %%
# %cd text-generation-webui
# Out:
# /content/text-generation-webui

# %%
# !python server.py --auto-devices --chat --share --model-dir models
# Out:
# 07:16:35-467843 INFO     Starting Text generation web UI
# 07:16:35-472785 INFO     Loading the extension "gallery"
#
# Running on local URL:  http://127.0.0.1:7860
#
# Running on public URL: https://d356f27329ce0cee98.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/gradio/queueing.py", line 407, in call_prediction
#     output = await route_utils.call_process_api(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/route_utils.py", line 226, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 1550, in process_api
#     result = await self.call_function(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 1185, in call_function
# ...
