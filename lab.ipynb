# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !df -Th
# Out:
# Filesystem     Type     Size  Used Avail Use% Mounted on
# overlay        overlay  202G   38G  164G  19% /
# tmpfs          tmpfs     64M     0   64M   0% /dev
# shm            tmpfs     41G     0   41G   0% /dev/shm
# /dev/root      ext2     2.0G  1.1G  849M  57% /usr/sbin/docker-init
# tmpfs          tmpfs     42G   44K   42G   1% /var/colab
# /dev/sda1      ext4     242G   79G  164G  33% /kaggle/input
# tmpfs          tmpfs     42G     0   42G   0% /proc/acpi
# tmpfs          tmpfs     42G     0   42G   0% /proc/scsi
# tmpfs          tmpfs     42G     0   42G   0% /sys/firmware

# %%
# !free -g
# Out:
#                total        used        free      shared  buff/cache   available
# Mem:              83           0          79           0           3          82
# Swap:              0           0           0

# %%
# !nvidia-smi
# Out:
# Tue Mar 26 11:18:18 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0              42W / 400W |      2MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# ...

# %%
# !bash /content/drive/MyDrive/Colab\ Notebooks/google-colab-local-llm/install-text-generation-webui.sh
# Out:
# bash: /content/drive/MyDrive/Colab Notebooks/google-colab-local-llm/install-text-generation-webui.sh: No such file or directory

# %%
# !bash /content/drive/MyDrive/Colab\ Notebooks/google-colab-local-llm/download-llms.sh
# Out:
# bash: /content/drive/MyDrive/Colab Notebooks/google-colab-local-llm/download-llms.sh: No such file or directory

# %%
# !python server.py --auto-devices --chat --share --model-dir /content/model
# Out:
# python3: can't open file '/content/server.py': [Errno 2] No such file or directory
